# %% [markdown]
# <a href="https://colab.research.google.com/github/22040223-max/Machine-Deep-Learning/blob/main/Unidad1/Practica1_Alan_Eduardo_Fern%C3%A1ndez_Varela.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Maching y Deep Leraning
# # unidad 1
#
# ## Practica 1: 'data
#
# ### docente: Dr. Jose Gabriel Rodriguez Rivas
#
# ### Alumno: Fernandez Varela Alan Eduardo_________________________________-

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.pyplot as pyplot
import numpy as np

# %%
autos = pd.read_csv("AutosDatosSucios.csv")

# %%
autos.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
#    fuel-system  bore  stroke compression-ratio horsepower  peak-rpm city-mpg  \
# 0         mpfi  3.47    2.68               9.0        111      5000       21
# 1         mpfi  3.47    2.68               9.0        111      5000       21
# 2         mpfi  2.68    3.47               9.0        154      5000       19
# 3         mpfi  3.19     3.4              10.0        102      5500       24
# 4         mpfi  3.19     3.4               8.0        115      5500       18
#
#   highway-mpg  price
# 0          27  13495
# 1          27  16500
# 2          26  16500
# 3          30  13950
# 4          22  17450
#
# [5 rows x 26 columns]

# %%
autos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  205 non-null    object
#  2   make               205 non-null    object
#  3   fuel-type          205 non-null    object
#  4   aspiration         205 non-null    object
#  5   num-of-doors       205 non-null    object
#  6   body-style         205 non-null    object
#  7   drive-wheels       205 non-null    object
#  8   engine-location    205 non-null    object
#  9   wheel-base         205 non-null    float64
#  10  length             205 non-null    float64
#  11  width              205 non-null    float64
#  12  height             205 non-null    float64
#  13  curb-weight        205 non-null    int64
#  14  engine-type        205 non-null    object
#  15  num-of-cylinders   205 non-null    object
#  16  engine-size        205 non-null    int64
#  17  fuel-system        205 non-null    object
#  18  bore               205 non-null    object
#  19  stroke             205 non-null    object
#  20  compression-ratio  205 non-null    float64
#  21  horsepower         205 non-null    object
#  22  peak-rpm           205 non-null    object
#  23  city-mpg           205 non-null    int64
#  24  highway-mpg        205 non-null    int64
#  25  price              205 non-null    object
# dtypes: float64(5), int64(5), object(16)
# memory usage: 41.8+ KB

# %%
autos.replace("?", np.nan, inplace=True)
autos.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3               NaN  alfa-romero       gas        std          two
# 1          3               NaN  alfa-romero       gas        std          two
# 2          1               NaN  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
#    fuel-system  bore  stroke compression-ratio horsepower  peak-rpm city-mpg  \
# 0         mpfi  3.47    2.68               9.0        111      5000       21
# 1         mpfi  3.47    2.68               9.0        111      5000       21
# 2         mpfi  2.68    3.47               9.0        154      5000       19
# 3         mpfi  3.19     3.4              10.0        102      5500       24
# 4         mpfi  3.19     3.4               8.0        115      5500       18
#
#   highway-mpg  price
# 0          27  13495
# 1          27  16500
# 2          26  16500
# 3          30  13950
# 4          22  17450
#
# [5 rows x 26 columns]

# %%
#Contar valores perdidos en la columna normalized-losses
autos["normalized-losses"].isnull().value_counts()
# Out:
# normalized-losses
# False    164
# True      41
# Name: count, dtype: int64

# %%
#Contar valores perdidos en todas las columnas
autos.isna().sum().sort_values()
# Out:
# symboling             0
# make                  0
# fuel-type             0
# aspiration            0
# drive-wheels          0
# body-style            0
# wheel-base            0
# engine-location       0
# height                0
# curb-weight           0
# length                0
# width                 0
# engine-type           0
# num-of-cylinders      0
# fuel-system           0
# engine-size           0
# highway-mpg           0
# compression-ratio     0
# city-mpg              0
# num-of-doors          2
# peak-rpm              2
# horsepower            2
# bore                  4
# stroke                4
# price                 4
# normalized-losses    41
# dtype: int64

# %%
avg_norm_loss = autos["normalized-losses"].astype("float").mean(axis=0)
print ("Promedio de normalized-losses: ", avg_norm_loss)
# Out:
# Promedio de normalized-losses:  122.0

# %%
autos["normalized-losses"].replace(np.nan, avg_norm_loss, inplace = True)
# Out:
# /tmp/ipykernel_2815/1721970274.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   autos["normalized-losses"].replace(np.nan, avg_norm_loss, inplace = True)

# %%
avg_stroke = autos['stroke'].astype('float').mean(axis=0)
print ("Promedio de stroke: ", avg_stroke)
# Out:
# Promedio de stroke:  3.255422885572139

# %%
autos["stroke"].replace(np.nan, avg_stroke, inplace = True)
# Out:
# /tmp/ipykernel_2815/3158154555.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   autos["stroke"].replace(np.nan, avg_stroke, inplace = True)

# %%
avg_bore = autos['bore'].astype('float').mean(axis=0)
print ("Promedio de bore: ", avg_bore)
# Out:
# Promedio de bore:  3.330710659898477

# %%
autos["bore"].replace(np.nan, avg_bore, inplace = True)
# Out:
# /tmp/ipykernel_2815/3178325296.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   autos["bore"].replace(np.nan, avg_bore, inplace = True)

# %%
avg_horsepower = autos['horsepower'].astype('float').mean(axis=0)
print ("Promedio de horsepower: ", avg_horsepower)
# Out:
# Promedio de horsepower:  103.39698492462311

# %%
autos["horsepower"] = autos["horsepower"].astype("float")

# %%
avg_peakrpm = autos['peak-rpm'].astype('float').mean(axis=0)
print ("Promedio de peak: ", avg_peakrpm)
# Out:
# Promedio de peak:  5117.587939698493

# %%
autos["peak-rpm"].replace(np.nan, avg_peakrpm, inplace = True)
# Out:
# /tmp/ipykernel_2815/2805080290.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   autos["peak-rpm"].replace(np.nan, avg_peakrpm, inplace = True)

# %%
autos['num-of-doors'].value_counts()
# Out:
# num-of-doors
# four    114
# two      89
# Name: count, dtype: int64

# %%
plt.hist(autos['horsepower'], bins = 3)
plt.xlabel("Caballos de Fuerza")
plt.ylabel("Cantidad")
plt.title("Contenedores Horsepower")
# Out:
# Text(0.5, 1.0, 'Contenedores Horsepower')

# %%
autos.dropna(subset=["price"], axis = 0, inplace = True)

# %%
autos.dtypes
# Out:
# symboling              int64
# normalized-losses     object
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                  object
# stroke                object
# compression-ratio    float64
# horsepower            object
# peak-rpm              object
# city-mpg               int64
# highway-mpg            int64
# price                 object
# dtype: object

# %%
autos[["bore","stroke"]] = autos[["bore","stroke"]].astype("float")
autos[["normalized-losses"]] = autos[["normalized-losses"]].astype("int")
autos[["price"]] = autos[["price"]].astype("float")
autos[["peak-rpm"]] = autos[["peak-rpm"]].astype("float")

# %%
#creamos una nueva columna con la conversion de ñas unidades
# La formula de conversion es
# L/100km'] = 235 / autos
autos['city-L/100km'] = 235 / autos["city-mpg"]

# %%
#Enseguida vamos a tranformar los datos de la columna
# Millas por galon en carretera
# L/100km'] = 235 / autos
autos["highway-L/100km"] = 235 / autos["highway-mpg"]
autos.rename(columns={"highway-mpg":"highway-L/100km"}, inplace = True)

# %%
autos.head()
# Out:
#    symboling  normalized-losses         make fuel-type aspiration  \
# 0          3                122  alfa-romero       gas        std
# 1          3                122  alfa-romero       gas        std
# 2          1                122  alfa-romero       gas        std
# 3          2                164         audi       gas        std
# 4          2                164         audi       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0          two  convertible          rwd           front        88.6  ...
# 1          two  convertible          rwd           front        88.6  ...
# 2          two    hatchback          rwd           front        94.5  ...
# 3         four        sedan          fwd           front        99.8  ...
# 4         four        sedan          4wd           front        99.4  ...
#
#    horsepower  peak-rpm  city-mpg  highway-L/100km    price city-L/100km  \
# 0       111.0    5000.0        21               27  13495.0    11.190476
# 1       111.0    5000.0        21               27  16500.0    11.190476
# 2       154.0    5000.0        19               26  16500.0    12.368421
# 3       102.0    5500.0        24               30  13950.0     9.791667
# 4       115.0    5500.0        18               22  17450.0    13.055556
#
#    highway-L/100km fuel-type-map  fuel-type_code  horsepower-binned
# 0         8.703704             1               1                Low
# 1         8.703704             1               1                Low
# 2         9.038462             1               1             Medium
# 3         7.833333             1               1                Low
# 4        10.681818             1               1                Low
#
# [5 rows x 31 columns]

# %%
autos[["length", "width", "height"]].head()
# Out:
#      length     width    height
# 0  0.811148  0.890278  0.816054
# 1  0.811148  0.890278  0.816054
# 2  0.822681  0.909722  0.876254
# 3  0.848630  0.919444  0.908027
# 4  0.848630  0.922222  0.908027

# %%
autos["length"] = autos["length"] / autos["length"].max()
autos["width"] = autos["width"] / autos["width"].max()
autos["height"] = autos["height"] / autos["height"].max()

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

autos["fuel-type_code"] = le.fit_transform(autos["fuel-type"])

# %%
autos["fuel-type_code"] = le.fit_transform(autos["fuel-type"])

# %%
autos["fuel-type"].value_counts()
# Out:
# fuel-type
# gas       181
# diesel     20
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
variable_dummy1 = pd.get_dummies(autos["fuel-type"])
variable_dummy1.head()
# Out:
#    diesel   gas
# 0   False  True
# 1   False  True
# 2   False  True
# 3   False  True
# 4   False  True

# %%
mapeo_dicc = {'diesel':0, 'gas':1}
autos['fuel-type-map'] = autos["fuel-type"].map(mapeo_dicc)

# %%
autos.head()
# Out:
#    symboling  normalized-losses         make fuel-type aspiration  \
# 0          3                122  alfa-romero       gas        std
# 1          3                122  alfa-romero       gas        std
# 2          1                122  alfa-romero       gas        std
# 3          2                164         audi       gas        std
# 4          2                164         audi       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0          two  convertible          rwd           front        88.6  ...
# 1          two  convertible          rwd           front        88.6  ...
# 2          two    hatchback          rwd           front        94.5  ...
# 3         four        sedan          fwd           front        99.8  ...
# 4         four        sedan          4wd           front        99.4  ...
#
#    horsepower  peak-rpm  city-mpg  highway-L/100km    price city-L/100km  \
# 0       111.0    5000.0        21               27  13495.0    11.190476
# 1       111.0    5000.0        21               27  16500.0    11.190476
# 2       154.0    5000.0        19               26  16500.0    12.368421
# 3       102.0    5500.0        24               30  13950.0     9.791667
# 4       115.0    5500.0        18               22  17450.0    13.055556
#
#    highway-L/100km fuel-type-map  fuel-type_code  horsepower-binned
# 0         8.703704             1               1                Low
# 1         8.703704             1               1                Low
# 2         9.038462             1               1             Medium
# 3         7.833333             1               1                Low
# 4        10.681818             1               1                Low
#
# [5 rows x 31 columns]

# %%
autos.tail()
# Out:
#      symboling  normalized-losses   make fuel-type aspiration num-of-doors  \
# 200         -1                 95  volvo       gas        std         four
# 201         -1                 95  volvo       gas      turbo         four
# 202         -1                 95  volvo       gas        std         four
# 203         -1                 95  volvo    diesel      turbo         four
# 204         -1                 95  volvo       gas      turbo         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  \
# 200      sedan          rwd           front       109.1  ...
# 201      sedan          rwd           front       109.1  ...
# 202      sedan          rwd           front       109.1  ...
# 203      sedan          rwd           front       109.1  ...
# 204      sedan          rwd           front       109.1  ...
#
#      compression-ratio  horsepower  peak-rpm  city-mpg highway-L/100km  \
# 200                9.5         114    5400.0        23              28
# 201                8.7         160    5300.0        19              25
# 202                8.8         134    5500.0        18              23
# 203               23.0         106    4800.0        26              27
# 204                9.5         114    5400.0        19              25
#
#        price  city-L/100km highway-L/100km  fuel-type-map  fuel-type_code
# 200  16845.0     10.217391        8.392857              1               1
# 201  19045.0     12.368421        9.400000              1               1
# 202  21485.0     13.055556       10.217391              1               1
# 203  22470.0      9.038462        8.703704              0               0
# 204  22625.0     12.368421        9.400000              1               1
#
# [5 rows x 30 columns]

# %%
plt.hist(autos['horsepower'], bins = 3)
plt.xlabel("Caballos de Fuerza")
plt.ylabel("Cantidad")
plt.title("Contenedores Horsepower")
# Out:
# Text(0.5, 1.0, 'Contenedores Horsepower')

# %%
#Contenedores del rango de valores
bins = np.linspace(min(autos['horsepower']), max(autos['horsepower']), 4)
bins
# Out:
# array([ 48.        , 119.33333333, 190.66666667, 262.        ])

# %%
#definimos los nombres de los grupos que seran las variables categoricas
#de acuerdo al valor de horsepower

grupos = ['Low', 'Medium', 'High']


autos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 201 entries, 0 to 204
# Data columns (total 30 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          201 non-null    int64
#  1   normalized-losses  201 non-null    int64
#  2   make               201 non-null    object
#  3   fuel-type          201 non-null    object
#  4   aspiration         201 non-null    object
#  5   num-of-doors       199 non-null    object
#  6   body-style         201 non-null    object
#  7   drive-wheels       201 non-null    object
#  8   engine-location    201 non-null    object
#  9   wheel-base         201 non-null    float64
#  10  length             201 non-null    float64
#  11  width              201 non-null    float64
#  12  height             201 non-null    float64
#  13  curb-weight        201 non-null    int64
#  14  engine-type        201 non-null    object
#  15  num-of-cylinders   201 non-null    object
#  16  engine-size        201 non-null    int64
#  17  fuel-system        201 non-null    object
#  18  bore               197 non-null    float64
#  19  stroke             201 non-null    float64
#  20  compression-ratio  201 non-null    float64
#  21  horsepower         199 non-null    float64
#  22  peak-rpm           199 non-null    float64
#  23  city-mpg           201 non-null    int64
#  24  highway-L/100km    201 non-null    int64
#  25  price              201 non-null    float64
#  26  city-L/100km       201 non-null    float64
#  27  highway-L/100km    201 non-null    float64
#  28  fuel-type-map      201 non-null    int64
#  29  fuel-type_code     201 non-null    int64
# dtypes: float64(12), int64(8), object(10)
# memory usage: 48.7+ KB

# %%
autos ['horsepower-binned'] = pd.cut(autos['horsepower'], bins, labels = grupos, include_lowest = True)


autos[['horsepower','horsepower-binned']].head(20)
# Out:
#     horsepower horsepower-binned
# 0        111.0               Low
# 1        111.0               Low
# 2        154.0            Medium
# 3        102.0               Low
# 4        115.0               Low
# 5        110.0               Low
# 6        110.0               Low
# 7        110.0               Low
# 8        140.0            Medium
# 10       101.0               Low
# 11       101.0               Low
# 12       121.0            Medium
# 13       121.0            Medium
# 14       121.0            Medium
# 15       182.0            Medium
# 16       182.0            Medium
# 17       182.0            Medium
# 18        48.0               Low
# 19        70.0               Low
# 20        70.0               Low

# %%
autos['horsepower-binned'].value_counts()
# Out:
# horsepower-binned
# Low       151
# Medium     43
# High        5
# Name: count, dtype: int64

# %%
# Volvemos a graficar la distribucion de la nueva columna etiquetada de categorías
plt.bar(grupos, autos["horsepower-binned"].value_counts())
plt.xlabel("Caballos de Fuerza")
plt.ylabel("Cantidad")
plt.title("Contenedores horsepower")
# Out:
# Text(0.5, 1.0, 'Contenedores horsepower')

# %%
autos.to_csv('autos_corregidos.csv', index = False)
